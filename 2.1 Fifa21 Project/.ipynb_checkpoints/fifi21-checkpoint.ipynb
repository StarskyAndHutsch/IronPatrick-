# %% [markdown]
# ## FIFA

# %%
#Import Libraries
import pandas as pd
import numpy as np
fifa21 = pd.read_csv ('fifa21_train.csv')
fifa21.sample(7)
# Out:
#            ID               Name  Age Nationality          Club   BP  \
# 4869   227807          M. Folivi   21     England       Watford   ST
# 2810   212878        N. Castillo   27       Chile  Club América   ST
# 397    237735  Matheus Fernandes   22      Brazil  FC Barcelona   CM
# 10282  225116           A. Meret   23       Italy        Napoli   GK
# 6899   205869              Jairo   26       Spain     Málaga CF   LM
# 8718   172077         J. Basanta   35   Argentina     Monterrey   CB
# 9971   224265        J. Williams   23     England  Bristol City  CDM
#
#          Position           Team & Contract Height  Weight  ...   CDM   RDM  \
# 4869           ST       Watford 2015 ~ 2020   5'9"  174lbs  ...  37+2  37+2
# 2810           ST  Club América 2019 ~ 2022  5'10"  179lbs  ...  53+2  53+2
# 397            CM  FC Barcelona 2020 ~ 2025   6'0"  157lbs  ...  68+2  68+2
# 10282          GK        Napoli 2018 ~ 2023   6'3"  183lbs  ...  27+2  27+2
# ...

# %%
fifa21
# Out:
#            ID            Name  Age  Nationality                        Club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
# ...

# %%
fifa21.columns = fifa21.columns.str.lower()

# %%
fifa21
# Out:
#            id            name  age  nationality                        club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
# ...

# %%
fifa21.columns = fifa21.columns.str.replace(' ', '_')

# %%
fifa21
# Out:
#            id            name  age  nationality                        club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
# ...

# %%
list_columns=[]
for i in list_columns:
    fifa21[i].str[:-2]
list_columns
print(fifa21.columns)
# Out:
# Index(['id', 'name', 'age', 'nationality', 'club', 'bp', 'position',
#        'team_&_contract', 'height', 'weight',
#        ...
#        'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'ova'],
#       dtype='object', length=101)

# %%
fifa21
# Out:
#            id            name  age  nationality                        club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
# ...

# %%
fifa21['st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb','cb', 'rcb', 'rb', 'gk'].str[:-2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
fifa21_clean=fifa21.drop(columns=['name', 'age', 'nationality', 'club', 'team & contract', 'joined', 'loan date end', 'value', 'wage', 'release clause', 'contract', 'crossing', 'finishing', 'heading accuracy', 'short passing', 'volleys', 'dribbling', 'curve', 'fk accuracy', 'long passing', 'ball control', 'acceleration', 'sprint speed', 'agility', 'reactions', 'balance', 'shot power', 'jumping', 'stamina', 'strenght', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'marking', 'pac', 'sho', 'pas', 'def', 'phy'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 fifa21_clean=fifa21.drop(columns=['name', 'age', 'nationality', 'club', 'team & contract', 'joined', 'loan date end', 'value', 'wage', 'release clause', 'contract', 'crossing', 'finishing', 'heading accuracy', 'short passing', 'volleys', 'dribbling', 'curve', 'fk accuracy', 'long passing', 'ball control', 'acceleration', 'sprint speed', 'agility', 'reactions', 'balance', 'shot power', 'jumping', 'stamina', 'strenght', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'marking', 'pac', 'sho', 'pas', 'def', 'phy'])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
# ...

# %%
fifa21_clean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 fifa21_clean
#
# NameError: name 'fifa21_clean' is not defined

# %%
fifa21.columns[fifa.isnull().any()]

# %%
org_string = 'Sample String' 
size = len(org_string)
mod_string = org_string[:size - 1]
print (mod_string)

# %%
fifa.columns

# %%
fifa.columns

# %%
print(fifa)

# %%
fifa['st', 'rs','lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb','cb', 'rcb', 'rb', 'gk'].str[:-2]

# %%
print (fifa.columns)

# %%
list_columns = [ ...
for i list–columns:
    fifa[i].str[-2]

# %%
fifa.columns

# %%
list_columns =[]
for i in list_columns:
    fifa[i].str[:-2]
list_columns
fifa.columns = cols
print(cols)

# %%
print(head)

# %%
fifa.sample(7)

# %%
fifa.columns

# %%
# Check for missing values
fifa.columns[fifa.isnull().any()]

# %%
print(message.lower())

# %%
ls

# %%
fifa.columns

# %%
fifa['LS'].str.split('+',n=1,expand=True)[0]

# %%
def split (column):
    fifa[column].str.split('+',n=1,expand=True)[0]
    fifa[column] = fifa[column].str.split
    return fifa[column]

# %%
list_column ['ST', 'RS','LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB','CB', 'RCB', 'RB', 'GK']
fifa[column].str.split
for i in list_columns:
    for c in fifa.columns:
        if i==c:

# %%
fifa

# %%
fifa_clean=fifa.drop(columns=['ID', 'Name', 'Age', 'Nationality', 'Club', 'Team & Contract', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause', 'Contract', 'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing','Ball Control', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Reactions', 'Balance', 'Shot Power', 'Jumping', 'Stamina', ' 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking'])

# %%
fifa_clean

# %%
fifa_clean.columns

# %%
fifa_clean=fifa_clean.drop(columns=['PAC', 'SHO', 'PAS', 'DEF', 'PHY'])

# %%
fifa_clean.columns

# %%
fifa_clean

# %%
fifa_clean.columns

# %%
fifa_clean=fifa_clean.drop(columns=['Sliding Tackle', 'Standing Tackle', 'Long Shots'])

# %%
fifa_clean

# %%
fifa_clean.columns

# %%
fifa21_clean=fifa_clean.drop(columns=['Strenght'])

# %%
fifa_clean

# %%
fifa_clean.columns

# %%
fifa_clean=fifa_clean.drop(['Strenght'])

# %%
fifa_clean.columns

# %%
fifa_clean

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.random.random((16, 16))
plt.imshow(a, cmap='hot', interpolation='nearest')
plt.show()

# %%
fifa_clean.dtypes
